# %%
# %reset -f

# %%
import numpy as np
import tensorflow_datasets as tfds
import tensorflow as tf  # For tf.data
import matplotlib.pyplot as plt
import keras
from keras import layers
from keras.applications import EfficientNetB6
from tensorflow.keras.callbacks import EarlyStopping

# IMG_SIZE is determined by EfficientNet model choice
IMG_SIZE = 528
BATCH_SIZE = 64
# Out:
# 2024-12-22 16:29:42.075421: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-22 16:29:42.076538: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-22 16:29:42.080042: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-22 16:29:42.086879: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1734877782.098809  172197 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1734877782.102256  172197 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-22 16:29:42.115528: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load the dataset

dataset_dir = "/home/clap/Documents/miniproject_bioinformatic/dataset/dataset_beans_split/sample_150"
builder = tfds.ImageFolder(dataset_dir)
ds_train, ds_test, ds_val = builder.as_dataset(
    split=["train", "test", "validation"], as_supervised=True
)
ds_info = builder.info
NUM_CLASSES = builder.info.features["label"].num_classes


size = (IMG_SIZE, IMG_SIZE)
ds_val = ds_val.map(lambda image, label: (tf.image.resize(image, size), label))
ds_test = ds_test.map(lambda image, label: (tf.image.resize(image, size), label))
ds_train = ds_train.map(lambda image, label: (tf.image.resize(image, size), label))
# Out:
# 2024-12-22 16:29:43.564252: W external/local_tsl/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "FAILED_PRECONDITION: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Could not resolve host: metadata.google.internal".
# 2024-12-22 16:29:44.026698: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
def format_label(label):
    string_label = label_info.int2str(label)
    return string_label

beansImages = {}
label_info = ds_info.features["label"]
for label_name in label_info.names:
    beansImages[label_name] = []
for i, (image, label) in enumerate(ds_train):
    beansImages[format_label(label)].append(image)
for label_name in label_info.names:
    print (f"Total of {label_name} leaves: {len(beansImages[label_name])}")
# Out:
# Total of angular_leaf_spot leaves: 50
# Total of bean_rust leaves: 50
# Total of healthy leaves: 49
# 2024-12-22 16:29:44.275098: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
import random

def plot_sample_images():
    fig, axes = plt.subplots(3, 3, figsize=(10, 10))
    fig.subplots_adjust(hspace=0.5)
    fig.suptitle('Samples of leavs')
    for i, label in enumerate(beansImages.keys()):
        for j in range(3):
            randeom_index = random.randint(0, len(beansImages[label]) -1)	
            img = beansImages[label][randeom_index].numpy().astype("uint8")
            axes[i, j].imshow(img)
            axes[i, j].axis('off')
            axes[i, j].set_title(label)
    plt.show()
plot_sample_images()

# %%
img_augmentation_layers = [
    layers.RandomRotation(factor=0.15),
    layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
    layers.RandomFlip(),
    layers.RandomContrast(factor=0.1),
    layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    layers.RandomBrightness(factor=0.2),
    layers.GaussianNoise(0.1)
]


def img_augmentation(images):
    for layer in img_augmentation_layers:
        images = layer(images)
    return images

# %%
# One-hot / categorical encoding
def input_preprocess_train(image, label):
    image = img_augmentation(image)
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label


def input_preprocess_test(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label


ds_train = ds_train.map(input_preprocess_train, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.batch(batch_size=BATCH_SIZE, drop_remainder=True)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

ds_val = ds_val.map(input_preprocess_test, num_parallel_calls=tf.data.AUTOTUNE)
ds_val = ds_val.batch(batch_size=BATCH_SIZE, drop_remainder=True)

ds_test = ds_test.map(input_preprocess_test, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(batch_size=BATCH_SIZE, drop_remainder=True)

# %%
import matplotlib.pyplot as plt


def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()

# %%
def build_model(num_classes):
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    base_model = EfficientNetB6(include_top=False, input_tensor=inputs, weights="imagenet")
    
    # Freeze all layers initially
    base_model.trainable = False

    # Add classification head
    x = layers.GlobalAveragePooling2D(name="avg_pool")(base_model.output)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(256, activation="relu", name="dense_before_output")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3, name="dropout_before_output")(x)
    outputs = layers.Dense(num_classes, activation="softmax", name="pred")(x)

    # Compile the model
    model = keras.Model(inputs, outputs, name="EfficientNet")
    
    optimizer = keras.optimizers.Adam(learning_rate=1e-3)  # Reduced learning rate
    model.compile(
        optimizer=optimizer, 
        loss="categorical_crossentropy", 
        metrics=["accuracy"]
    )

    return model

# %%
model = build_model(num_classes=NUM_CLASSES)
early_stopping = EarlyStopping(
    monitor='val_loss',  # Metric to monitor
    patience=4,          # Stop training after 4 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)
hist = model.fit(
    ds_train,
    epochs=50,
    validation_data=ds_val,
      callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 99s 65s/step - accuracy: 0.4896 - loss: 1.2760 - val_accuracy: 0.6484 - val_loss: 0.8891
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 85s 63s/step - accuracy: 0.7969 - loss: 0.6120 - val_accuracy: 0.7109 - val_loss: 0.7720
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.8594 - loss: 0.5480 - val_accuracy: 0.7422 - val_loss: 0.7077
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.8854 - loss: 0.4219 - val_accuracy: 0.8047 - val_loss: 0.6667
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9375 - loss: 0.1923 - val_accuracy: 0.8125 - val_loss: 0.6434
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9219 - loss: 0.1867 - val_accuracy: 0.7969 - val_loss: 0.6419
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9062 - loss: 0.2333 - val_accuracy: 0.7891 - val_loss: 0.6501
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9479 - loss: 0.2112 - val_accuracy: 0.7891 - val_loss: 0.6567
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9583 - loss: 0.1258 - val_accuracy: 0.7812 - val_loss: 0.6524
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9792 - loss: 0.0998 - val_accuracy: 0.7812 - val_loss: 0.6310
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9688 - loss: 0.0745 - val_accuracy: 0.7891 - val_loss: 0.6163
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9844 - loss: 0.1015 - val_accuracy: 0.7891 - val_loss: 0.6062
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9531 - loss: 0.1469 - val_accuracy: 0.7891 - val_loss: 0.5995
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9583 - loss: 0.1452 - val_accuracy: 0.7891 - val_loss: 0.5864
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9688 - loss: 0.0734 - val_accuracy: 0.8047 - val_loss: 0.5751
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9740 - loss: 0.0639 - val_accuracy: 0.8125 - val_loss: 0.5554
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9740 - loss: 0.0838 - val_accuracy: 0.8125 - val_loss: 0.5535
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9844 - loss: 0.0419 - val_accuracy: 0.8125 - val_loss: 0.5544
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 64s/step - accuracy: 0.9792 - loss: 0.0591 - val_accuracy: 0.8125 - val_loss: 0.5511
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 88s 65s/step - accuracy: 0.9635 - loss: 0.0945 - val_accuracy: 0.8281 - val_loss: 0.5406
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9792 - loss: 0.0678 - val_accuracy: 0.8203 - val_loss: 0.5266
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9635 - loss: 0.0968 - val_accuracy: 0.8516 - val_loss: 0.5017
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9948 - loss: 0.0570 - val_accuracy: 0.8438 - val_loss: 0.4810
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9948 - loss: 0.0239 - val_accuracy: 0.8594 - val_loss: 0.4654
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9844 - loss: 0.0372 - val_accuracy: 0.8750 - val_loss: 0.4558
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9635 - loss: 0.0919 - val_accuracy: 0.8828 - val_loss: 0.4503
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9635 - loss: 0.1347 - val_accuracy: 0.8672 - val_loss: 0.4483
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9740 - loss: 0.0618 - val_accuracy: 0.8594 - val_loss: 0.4480
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9740 - loss: 0.0528 - val_accuracy: 0.8672 - val_loss: 0.4448
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 1.0000 - loss: 0.0259 - val_accuracy: 0.8672 - val_loss: 0.4425
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9896 - loss: 0.0394 - val_accuracy: 0.8672 - val_loss: 0.4378
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9896 - loss: 0.0273 - val_accuracy: 0.8750 - val_loss: 0.4332
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9948 - loss: 0.0367 - val_accuracy: 0.8750 - val_loss: 0.4261
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9948 - loss: 0.0232 - val_accuracy: 0.8984 - val_loss: 0.4180
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 1.0000 - loss: 0.0234 - val_accuracy: 0.8984 - val_loss: 0.4109
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9792 - loss: 0.0367 - val_accuracy: 0.8984 - val_loss: 0.4062
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9948 - loss: 0.0215 - val_accuracy: 0.8906 - val_loss: 0.4020
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.8828 - val_loss: 0.3984
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9740 - loss: 0.0488 - val_accuracy: 0.8828 - val_loss: 0.3925
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.8906 - val_loss: 0.3867
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9948 - loss: 0.0289 - val_accuracy: 0.8984 - val_loss: 0.3815
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9948 - loss: 0.0425 - val_accuracy: 0.8906 - val_loss: 0.3772
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9948 - loss: 0.0148 - val_accuracy: 0.8984 - val_loss: 0.3733
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 88s 65s/step - accuracy: 0.9896 - loss: 0.0227 - val_accuracy: 0.8984 - val_loss: 0.3690
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 88s 65s/step - accuracy: 0.9948 - loss: 0.0145 - val_accuracy: 0.8984 - val_loss: 0.3650
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 0.8984 - val_loss: 0.3615
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 88s 66s/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.8984 - val_loss: 0.3578
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 90s 66s/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.8984 - val_loss: 0.3539
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9062 - val_loss: 0.3508
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 64s/step - accuracy: 0.9896 - loss: 0.0192 - val_accuracy: 0.9062 - val_loss: 0.3477

# %%
# save the model 
#modelName = 'models/all.keras'
#model.save(modelName)

# %%
plot_hist(hist)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Step 1: Convert true labels to single-label format
true_labels = np.concatenate([np.argmax(y, axis=1) for x, y in ds_test], axis=0)

# Step 2: Get predicted labels (already handled with np.argmax)
predictions = model.predict(ds_test, batch_size=BATCH_SIZE)
predicted_labels = np.argmax(predictions, axis=1)

# Step 3: Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

class_names = ds_info.features['label'].names
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2024-12-22 17:42:14.961390: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 45s 21s/step

# %%
from sklearn.metrics import classification_report
# Calculate accuracy
accuracy = np.mean(true_labels == predicted_labels)
print(f"Accuracy: {accuracy:.2f}")
# Generate classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

print(report)
# Out:
# Accuracy: 0.90
#                    precision    recall  f1-score   support
#
# angular_leaf_spot       0.97      0.84      0.90        43
#         bean_rust       0.80      0.95      0.87        43
#           healthy       0.95      0.90      0.93        42
#
#          accuracy                           0.90       128
#         macro avg       0.91      0.90      0.90       128
#      weighted avg       0.91      0.90      0.90       128
